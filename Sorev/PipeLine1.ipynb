# %% [markdown]
# # Базовый комплект заготовок

# %%
import numpy as np
import pandas as pd
import random
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#test_df = read_csv('test_df.csv')

# %%
df = pd.read_csv("../data/cars.csv")

# %%
train = pd.read_csv('../data_sorev/train.csv')
test = pd.read_csv('../data_sorev/test.csv')

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt 
# %matplotlib inline


import seaborn as sns 
sns.set()

from scipy import stats
from scipy.stats import norm, skew

# %%
num_can = train.dtypes[train.dtypes!="object"].index.values

# %%
for col in num_can:
    print(col)
# Out:
# Id
# MSSubClass
# LotFrontage
# LotArea
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# MasVnrArea
# BsmtFinSF1
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# TotRmsAbvGrd
# Fireplaces
# GarageYrBlt
# GarageCars
# GarageArea
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# MiscVal
# MoSold
# YrSold
# SalePrice

# %%
for col in num_can:
    train.hist(col);
# Out:
# /home/ai/anaconda3/envs/ML_base/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:188: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %%
for col in num_can:
# Out:
#   File "<ipython-input-170-fd4a8834aaff>", line 1
#     for col in num_can:
#                        ^
# SyntaxError: unexpected EOF while parsing

# %%
def getInfo(df, target=None, a=None, b=None, c=None, i=0):
#Libs
    import numpy as np 
    import pandas as pd 
    import matplotlib.pyplot as plt 
    # %matplotlib inline
    import seaborn as sns 
    sns.set()
    from scipy import stats
    from scipy.stats import norm, skew
    import os


    if i == 0:
        cat_f = df.dtypes[df.dtypes=="object"].index.values
        num_f = df.dtypes[df.dtypes!="object"].index.values
        x = len(cat_f)
        y = len(num_f)
        print('There is', x, 'Categorical features (put i=5 to see names);', 'And there is', y, 'Numerical features (put i=6 to see names);', 'Shape is:', df.shape)
    
        return df.shape
    if i == 1:
        print('.head()')
        return df.head()
    
    if i == 2:
        print('.describe(include=all)')
        return df.describe(include='all')
    
    if i == 3:
        print('.info()')
        return df.info()
    
    if i == 4:
        x = len(df.columns)
        print(x, ' features:')
        return df.columns
    

    if i == 5:
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        x = len(num_candidates)
        print(x, 'Numerical features:')
        return num_candidates
    
    if i == 6:
        num_can = df.dtypes[df.dtypes!="object"].index.values
        for col in num_can:
            df.hist(col);
            
        return 'df_numerical.hist()'
    

    if i == 7:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        x = len(cat_candidates)
        print(x, ' Ctegorical features:')
        return cat_candidates

    if i == 8:
        if a == None:
            return 'You need put in categorical a'
        else:
            return sns.countplot(df[a]);
    
    if i == 9:
        if target == None:
            return 'You need put in target'
        else:
            plt.figure(figsize=(20,5))
            sns.distplot(df[target] , fit=norm);

            (mu, sigma) = norm.fit(df[target])
            print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))

            plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
            plt.ylabel('Frequency')
            plt.title('Target distribution')

            fig = plt.figure()
            res = stats.probplot(df[target], plot=plt)
         
        return plt.show()
    
    if i == 10:
        
        plt.figure(figsize=(30,8))
        sns.heatmap(df.corr(),cmap='coolwarm',annot = True)
        
        return plt.show()
    
    if i == 11:
        if a == None:
            return 'You need put in numerical ^a^'
        else:
            plt.figure(figsize=(20,5))
            sns.distplot(df[a] , fit=norm);

            (mu, sigma) = norm.fit(df[a])
            print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
            plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
            plt.ylabel('Frequency')
            plt.title(a)

            fig = plt.figure()
            res = stats.probplot(df[a], plot=plt)
            return plt.show()
        

    if i == 12:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        if a == None:
            return 'You need put in numerical a'
        elif a in cat_candidates:
            return 'a must be nemerical'
        elif b == None:
            return 'You need put in nemerical b'
        elif b in cat_candidates:
            return 'b must be nemerical'
        else:
            return sns.jointplot(x=b, y=a, data=df, kind='scatter'); 
        
        return 'ok'
        
        
    if i == 13:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        if a == None:
            return 'You need put in numerical a'
        elif a in cat_candidates:
            return 'a must be nemerical'
        elif b == None:
            return 'You need put in nemerical b'
        elif b in cat_candidates:
            return 'b must be nemerical'
        else:
            return sns.lmplot(x=b,y=a,data=df)        
        
        
    if i == 14:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        if a == None:
            return 'You need put in numerical a'
        elif a in cat_candidates:
            return 'a cannot be categorical'
        elif b == None:
            return 'You need put in categorical b'
        elif b in num_candidates:
            return 'b must be categorical'
        elif c == None:
            return 'You need put in categorical c'
        elif c in num_candidates:
            return 'c must be categorical'
        else:
            return df.pivot_table(a, b, c).plot(kind='bar', stacked=True)
        


       

    if i == 15:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        if a == None:
            return 'You need put in numerical a'
        elif a in cat_candidates:
            return 'a must be nemerical'
        elif b == None:
            return 'You need put in feature b'
        
        else:
            plt.figure(figsize=(16,8))
            sns.boxplot(x=b,y=a,data=df)

            return plt.show()
        
    if i == 16:
        cat_candidates = df.dtypes[df.dtypes=="object"].index.values
        num_candidates = df.dtypes[df.dtypes!="object"].index.values
        if a == None:
            return 'You need put in numerical a'
        elif a in cat_candidates:
            return 'a must be nemerical'
        elif b == None:
            return 'You need put in categorical b'
        
        else:
            
            return sns.violinplot(x=b, y=a, data=df);

      
        
    if i == 17:
        return 'ok'

    
    if i == 18:
        return 'ok'

    if i == 19:
        return 'ok'


    if i == 20:
        return 'ok'

# %%
getInfo(train, a='LowQualFinSF', i=7)
# Out:
# 38 Numerical features:
# array(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'], dtype=object)

# %%
getInfo(train, target='SalePrice', a='SalePrice', b='YearBuilt', c='ExterQual', i=12)

# %%
getInfo(train, i=15), getInfo(test)
# Out:
# There is 43 Categorical features (put i=5 to see names); And there is 37 Numerical features (put i=6 to see names); Shape is: (1459, 80)
# ('df_numerical.hist()', (1459, 80))

# %%
getInfo(train, i=8)
# Out:
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# 'df_categorical sns.countplot()'

# %%
getInfo(train, target='SalePrice', a='LotShape', b='OverallQual', c='LotShape', i=16)
# Out:
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# /n
# 'df_categorical sns.countplot()'

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
df.describe(include='all')
# Out:
#           Survived      Pclass                 Name   Sex         Age  \
# count   891.000000  891.000000                  891   891  714.000000
# unique         NaN         NaN                  891     2         NaN
# top            NaN         NaN  Baumann, Mr. John D  male         NaN
# freq           NaN         NaN                    1   577         NaN
# mean      0.383838    2.308642                  NaN   NaN   29.699118
# std       0.486592    0.836071                  NaN   NaN   14.526497
# min       0.000000    1.000000                  NaN   NaN    0.420000
# 25%       0.000000    2.000000                  NaN   NaN   20.125000
# 50%       0.000000    3.000000                  NaN   NaN   28.000000
# 75%       1.000000    3.000000                  NaN   NaN   38.000000
# max       1.000000    3.000000                  NaN   NaN   80.000000
#
#              SibSp       Parch Ticket        Fare        Cabin Embarked
# count   891.000000  891.000000    891  891.000000          204      889
# unique         NaN         NaN    681         NaN          147        3
# top            NaN         NaN   1601         NaN  C23 C25 C27        S
# freq           NaN         NaN      7         NaN            4      644
# mean      0.523008    0.381594    NaN   32.204208          NaN      NaN
# std       1.102743    0.806057    NaN   49.693429          NaN      NaN
# min       0.000000    0.000000    NaN    0.000000          NaN      NaN
# 25%       0.000000    0.000000    NaN    7.910400          NaN      NaN
# 50%       0.000000    0.000000    NaN   14.454200          NaN      NaN
# 75%       1.000000    0.000000    NaN   31.000000          NaN      NaN
# max       8.000000    6.000000    NaN  512.329200          NaN      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Name        891 non-null object
# Sex         891 non-null object
# Age         714 non-null float64
# SibSp       891 non-null int64
# Parch       891 non-null int64
# Ticket      891 non-null object
# Fare        891 non-null float64
# Cabin       204 non-null object
# Embarked    889 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
#df = train_df.drop('Cabin', axis=1).dropna()

# %%
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)
train_df['Embarked'].fillna('S', inplace=True)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df2 = df.reset_index()

# %%
df2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.pivot_table('Age', 'Survived', 'Pclass').plot(kind='bar', stacked=True)

# %%
fig, axes = plt.subplots(ncols=2)
df2.pivot_table('PassengerId', ['SibSp'], 'Survived', 'count').plot(ax=axes[0], title='SibSp')
df2.pivot_table('PassengerId', ['Parch'], 'Survived', 'count').plot(ax=axes[1], title='Parch')

# %%
df2.pivot_table('PassengerId', 'Pclass', 'Survived', 'count').plot(kind='bar', stacked=True)

# %%
df['Survived'].hist();

# %%
sns.boxplot(df['Age']);

# %%
df.hist();

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.countplot(df['Survived']);

# %%
sns.countplot(df['Embarked']);

# %%
sns.countplot(df['Age']);

# %%
sns.countplot(df[df['Age'].\
                 isin(df['Age'].value_counts().head().index)]['Age']);

# %%
feat = [f for f in df.columns if 'e' in f]

df[feat].hist();

# %%
sns.pairplot(df[feat]);

# %%
df3 = df2.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
sns.heatmap(df2.corr());

# %%
df4 = df2.drop(feat, axis=1, inplace=True)

# %%
sns.heatmap(df2.corr());

# %%
sns.boxplot(x='Survived', y='Age', data=df);

# %%
sns.boxplot(x='Pclass', y='Age', data=df);

# %%
sns.violinplot(x='Survived', y='Age', data=df);

# %%
sns.violinplot(x='Pclass', y='Age', data=df);

# %%
sns.countplot(x='Pclass', hue='Survived', data=df);

# %%
sns.countplot(x='Age', hue='Survived', data=df);

# %%
from sklearn.manifold import TSNE
tsne = TSNE(random_state=0)
df2 = df.drop(['State', 'Churn'], axis=1)

# %%
def write_to_submission_file(predicted_labels, out_file,
                             target='Delinquent90', index_label="client_id"):
    # turn predictions into data frame and save as csv file
    predicted_df = pd.DataFrame(predicted_labels,
                                index = np.arange(75000, 
                                                  predicted_labels.shape[0] + 75000),
                                columns=[target])
    predicted_df.to_csv(out_file, index_label=index_label)

# %%
write_to_submission_file(model_pred, 'credit_scoring_first_model.csv')

# %% [markdown]
# ### Деревья

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
first_tree = DecisionTreeClassifier(random_state=17)
first_tree.fit(X_train, y)

# %%
first_tree.predict(X_test)

# %%
first_tree.predict_proba(X_test)

# %%
from sklearn.model_selection import train_test_split, cross_val_score
np.mean(cross_val_score(first_tree, X_train, y_train, cv=6))

# %%
first_tree.score(X_train, y_train)

# %%
from sklearn.model_selection import GridSearchCV

first_tree.get_params()

# %%
tree_params = {'max_depth': list(range(3, 8)), 
               'min_samples_leaf': list(range(5, 13))}

locally_best_tree = GridSearchCV(first_tree, tree_params, cv=5, n_jobs=-1)
locally_best_tree.fit(X_train, y_train)

# %%
locally_best_tree.best_params_, round(locally_best_tree.best_score_, 3)

# %%
tuned_tree_pred = locally_best_tree.predict(X_test)

# %%
tuned_tree_pred_probs = locally_best_tree.predict_proba(test_df)[:, 1]

# %% [markdown]
# ## Ансамбли

# %% [markdown]
# ### Случайный лес

# %%
from sklearn.ensemble import RandomForestClassifier

first_forest = RandomForestClassifier(random_state=17)
first_forest.fit(X_train, y_train)

# %%
first_forest_pred = first_forest.predict(X_test)

# %%
first_forest_pred_prob = first_forest.predict_proba(X_test)[:, 1]

# %%
from sklearn.model_selection import GridSearchCV
# %%time
forest_params = {'max_features': np.linspace(.3, 1, 7)}

locally_best_forest = GridSearchCV(first_forest, forest_params, cv=8, n_jobs=-1)
locally_best_forest.fit(X_train, y_train)

# %%
locally_best_forest.best_params_, round(locally_best_forest.best_score_, 3)

# %%
tuned_forest_pred = locally_best_forest.predict(X_test)

# %%
tuned_forest_pred_proba = locally_best_forest.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Bagging
